# %% [markdown]
# Started on 05/28/25
#
# Looking at a costs-vs-infrastructure plot

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import math

import util

FOLDER = "/Users/brendan/Documents/projects/trails_project/julia/Paths/data/series/"

SIZE = 10000

# datafile = "/Users/brendan/Documents/projects/trails_project/julia/Paths/data/series/sayak_full_svd|2025-04-29/data.json"
# datafile = "/Users/brendan/Documents/projects/trails_project/julia/Paths/data/series/svd_100|2025-05-06/data.json"

# datafile = "/Users/brendan/Documents/projects/trails_project/julia/Paths/data/series/svd_data|2025-03-06/data.json"

datafiles = [
    "optimality_run|2025-05-28/data.json"
]

# %%
dfs = [
    util.load_data(FOLDER + datafile) for datafile in datafiles
]
df = pd.concat(dfs)
util.describe(df)
# Out:
# ratios: [50.0 55.0 60.0 65.0 70.0 75.0 80.0 85.0 90.0 95.0 100.0 105.0 110.0 115.0
#  120.0 125.0 130.0 135.0 140.0 145.0 150.0]
# patch recovery: [0.001]
# max costs: [2.0]
# boundary conditions: ['SOLID']
# num locations: [10]
# random walker seeds: 1
# random locations seeds: 1
# patch recovery logic: ['LINEAR']

# %%
sns.relplot(data=df[df["steps"] == 5000],
            x="totalImprovement",
            y="averageTravelCost",
            hue="ratio",
           )

# %%
sns.relplot(data=df[df["settings.numLocations"] == 20],
            x="steps",
            y="totalImprovement",
            style="settings.recoveryLogic",
            hue="settings.patchRecovery",
            col="settings.boundaryConditions",
            row="settings.randomSeedLocations"
)

# %%
sns.relplot(data=df,
            x="steps",
            y="totalImprovement",
            hue="settings.patchRecovery",
            col="settings.numLocations",
            row="settings.randomSeedLocations"
)
