# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

SIZE = 10000

datafile = "/Users/brendan/Documents/projects/trails_project/julia/Paths/data/series/svd_data|2025-03-06/data.json"

# %%
# load the json, and normalize into a dataframe
with open(datafile) as f:
    df = pd.json_normalize(json.load(f), record_path=["snapshots"], meta=[["settings", "patchRecovery"]])

# hopefully won't be necessary forever
df["run_id"] = [i // 201 for i in range(df.shape[0])]

# %%
def svd(df):
    patches = df["patches"]

    num_observations = len(patches)
    num_features = len(patches.iloc[0])
    # observations as rows, features as columns
    A = np.reshape(patches.explode(), (num_observations, num_features)).astype(float)
    # we actually *don't* want to demean A. they are already appropriately scaled and as centered as they need to be!
    # A = A - np.mean(A, axis=0)
    U, S, Vh = np.linalg.svd(A, full_matrices=False)

    # svd weight
    N = 100

    s = S**2/sum(S**2)
    plt.bar([x for x in range(N)], s[:N])
    plt.show()
    
    # plot the eigen-trails
    fig, axs = plt.subplots(2, 4)
    for i in range(8):
        ax = axs[i//4, i%4]
        ax.imshow(np.reshape(Vh[i], (100, 100)))
        ax.set_title(f"{i}:, {round(s[i], 3)}")

    return U, S, Vh

# %%
# just finals
# svd(df[(df["steps"] == 20000) & (df["settings.patchRecovery"] == 0.002)])

# %%
# half
svd(df[(df["steps"] >= 10000) & (df["settings.patchRecovery"] == 0.002)])
# Out:
# (array([[ 1.02514741e-02,  6.41455917e-04,  1.32137294e-02, ...,
#           0.00000000e+00,  8.52526131e-01,  0.00000000e+00],
#         [ 1.02786110e-02,  1.56029361e-03,  1.03491612e-02, ...,
#          -1.31976507e-03, -8.16673411e-02,  1.33082619e-01],
#         [ 1.00514367e-02, -1.65392771e-04,  1.11704227e-02, ...,
#          -8.70926006e-03, -1.11035136e-01, -5.88885597e-02],
#         ...,
#         [ 9.53284141e-03,  1.37018113e-02,  3.56123422e-03, ...,
#           1.50503510e-03, -4.35227511e-03,  2.89574617e-03],
#         [ 9.52441053e-03,  1.35326287e-02,  5.04428558e-03, ...,
#          -1.04563119e-02, -8.48360174e-04,  1.01816255e-02],
#         [ 9.61956419e-03,  1.30241262e-02,  4.58145428e-03, ...,
#          -4.64408878e-03, -2.76708285e-03,  2.80075770e-03]]),
#  array([2.30756540e+03, 4.31326271e+02, 3.16614535e+02, ...,
#         2.11993467e-13, 1.80745292e-13, 1.38191286e-13]),
#  array([[ 9.41791526e-19,  8.88178420e-16,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 3.15270533e-19, -1.21430643e-17, -6.07153217e-16, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 8.84742796e-18, -2.77555756e-17,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  1.00000000e+00],
#         [ 9.99915229e-01,  8.33740273e-03, -7.56111879e-03, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00, -7.23687461e-03,  1.72089340e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]))

# %%
# full
svd(df[df["settings.patchRecovery"] == 0.002])
# Out:
# (array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 9.24135915e-04,  1.48904595e-03, -1.08456811e-03, ...,
#           0.00000000e+00,  0.00000000e+00, -6.60825692e-01],
#         [ 1.45215191e-03,  2.85179087e-03, -7.76835170e-05, ...,
#           0.00000000e+00,  0.00000000e+00,  8.91190894e-06],
#         ...,
#         [ 7.37771460e-03,  1.73644814e-03,  5.72209307e-03, ...,
#           4.14010572e-03,  2.50107679e-03,  2.21870418e-03],
#         [ 7.37471969e-03,  1.78117781e-03,  5.76354603e-03, ...,
#           5.90875599e-03,  5.20771739e-03,  1.81404130e-03],
#         [ 7.45860446e-03,  2.01253458e-03,  4.25291362e-03, ...,
#           4.74615323e-03,  2.96252352e-03, -8.52828040e-04]]),
#  array([3.03162135e+03, 7.19150016e+02, 4.87432712e+02, ...,
#         2.73463795e-13, 2.73463795e-13, 1.80732713e-13]),
#  array([[ 0.00000000e+00,  8.33605803e-20,  2.77555756e-16, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  5.66224219e-19,  1.16573418e-15, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00, -6.08473958e-19, -4.99600361e-16, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  1.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  1.00000000e+00],
#         [ 0.00000000e+00, -9.99884851e-01,  4.67114099e-03, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]))

# %%
svd(df[(df["steps"] == 20000) & (df["settings.patchRecovery"] == 0.0002)]);

# %%
svd(df[(df["steps"] >= 10000) & (df["settings.patchRecovery"] == 0.0002)])

# %%
svd(df[(df["steps"] >= 0) & (df["settings.patchRecovery"] == 0.0002)])

# %%
U, S, Vt = svd(df[(df["steps"] == 20000) & (df["settings.patchRecovery"] == 0.002)])

# %%
colors = ["red"] * 100 + ["blue"] * 100
plt.scatter(U[:, 0], U[:, 1], c=colors)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(U[:, 0], U[:, 1], U[:, 2], c=colors, alpha=0.5)

# %%
U.shape

# %%
patches = df[(df["steps"] == 20000) & (df["settings.patchRecovery"] == 0.002)]["patches"]

num_observations = len(patches)
num_features = len(patches.iloc[0])
# observations as rows, features as columns
A = np.reshape(patches.explode(), (num_observations, num_features)).astype(float)
# we actually *don't* want to demean A. they are already appropriately scaled and as centered as they need to be!
# A = A - np.mean(A, axis=0)
U, S, Vh = np.linalg.svd(A, full_matrices=False)
V = Vh.T

# %%
S.shape

# %%
for i in range(5):
    df[f"U{i}"] = df["patches"].map(lambda p: p @ V[:, i] / S[i])

# %%
jdf = df[df["settings.patchRecovery"] == 0.002]

# %%
for i in range(5):
    sns.lineplot(data=jdf[jdf["steps"] <= 20000], x="steps", y=f"U{i}", hue="run_id", alpha=0.5)
    plt.show()

# %%
# patches = df[(df["steps"] == 20000) & (df["settings.patchRecovery"] == 0.0002)]["patches"]

# num_observations = len(patches)
# num_features = len(patches.iloc[0])
# # observations as rows, features as columns
# A = np.reshape(patches.explode(), (num_observations, num_features)).astype(float)
# # we actually *don't* want to demean A. they are already appropriately scaled and as centered as they need to be!
# # A = A - np.mean(A, axis=0)
# U, S, Vh = np.linalg.svd(A, full_matrices=False)
# V = Vh.T

# for i in range(5):
#     df[f"U{i}"] = df["patches"].map(lambda p: p @ V[:, i] / S[i])

sdf = df[df["settings.patchRecovery"] == 0.0002]

for i in range(5):
    sns.lineplot(data=sdf[sdf["steps"] <= 20000], x="steps", y=f"U{i}", hue="run_id", alpha=0.5)
    plt.show()

# %%
sns.relplot(data=sdf, x="U1", y="U2", hue="steps")
