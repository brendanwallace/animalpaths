# %% [markdown]
# compare different search algorithms

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import json

FILENAME = "series/series|2024-11-17|analyze_angles/data.json"

# %%
# with open(FILE1) as file1:
#     d1 = json.load(file1)
# with open(FILE2) as file2:
#     d2 = json.load(file2)
# with open(FILE3, 'w') as file3:
#     json.dump(d1+d2, file3)

# %%
with open("../data/" + FILENAME) as file:
    json_file = json.load(file)#, parse_float=lambda f: round(float(f), 2))
    data = pd.json_normalize(
        json_file,
        record_path=["snapshots"],
        meta=[
            ["settings", "maxCost"],
            ["settings", "patchImprovement"],
            ["settings", "patchRecovery"],
            ["settings", "searchStrategy"],
            ["settings", "recoveryLogic"],
        ],
    )

# %%
data["pI"] = data["settings.patchImprovement"]
data["pR"] = data["settings.patchRecovery"]
data["ratio"] = data["pI"] / data["pR"]
data["costRatio"] = data["averageTravelCost"] / data["settings.maxCost"]

# %%
data.columns
# Out:
# Index(['averageTravelCost', 'averageTravelLength', 'totalImprovement',
#        'thresholdImprovement', 'steps', 'settings.maxCost',
#        'settings.patchImprovement', 'settings.patchRecovery',
#        'settings.searchStrategy', 'settings.recoveryLogic', 'pI', 'pR',
#        'ratio', 'costRatio'],
#       dtype='object')

# %%
p = sns.relplot(
    data=data,
    x="steps",
    y="averageTravelCost",
    style="pR",
    hue="ratio",
    col="settings.searchStrategy",
    row="settings.maxCost",
    facet_kws={'sharey': "row"},
)

# %%
p = sns.relplot(
    data=data,
    x="steps",
    y="averageTravelLength",
    hue="ratio",
    col="settings.searchStrategy",
    row="settings.maxCost",
    facet_kws={'sharey': "row"},
)

# %%
p = sns.relplot(
    data=data,
    x="totalImprovement",
    y="averageTravelCost",
    row="settings.maxCost",
    hue="ratio",
    col="settings.searchStrategy",
    facet_kws={'sharey': "row"},

)

# %%
p = sns.relplot(
    data=data,
    x="steps",
    y="totalImprovement",
    hue="ratio",
    col="settings.searchStrategy",
    row="settings.maxCost",
    facet_kws={'sharey': "row"},
)

# %%
p = sns.relplot(
    data=data,
    x="steps",
    y="thresholdImprovement",
    hue="ratio",
    col="settings.searchStrategy",
    style="settings.maxCost",
)
