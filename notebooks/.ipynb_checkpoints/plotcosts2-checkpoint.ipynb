# %%
import numpy as np
import seaborn as sns
import pandas as pd

data = pd.read_csv("../data/randomFixed|100x100|maxCost=2.0.csv")

# %%
_data = data[(data["pI"] == 0.08) & (data["pR"] == 0.0001)]
data["ratio"] = data["pI"] / data["pR"]

# %%
sns.scatterplot(data=data, x="steps", y="improvements", style="pI", hue="pR")
# Out:
# <Axes: xlabel='steps', ylabel='improvements'>

# %%
sns.scatterplot(data=data, x="travelCosts", y="improvements", style="ratio", hue="steps")
# Out:
# <Axes: xlabel='travelCosts', ylabel='improvements'>

# %%
p = sns.scatterplot(data=_data, x="travelCosts", y="improvements", style="pI", hue="pR")

# %%
p = sns.scatterplot(data=data, x="travelCosts", y="improvements", style="ratio", hue="steps")

# %%
p = sns.scatterplot(data=data, x="travelCosts", y="improvements", hue="pR", style="pI")
# p.limit(x=(0, 120))
