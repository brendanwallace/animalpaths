# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
x = np.arange(100)
y = np.random.rand(100)

# %%
fig = plt.figure(figsize=(8, 6))
topfig, midfig, bottomfig = fig.subfigures(3, 1, height_ratios=(2, 2, 1))

topfig.set_facecolor('#cbe4c6ff')
topfig.suptitle('Top')

midfig.suptitle('Middle')
mid_axs = midfig.subplots(1, 3)

bottomfig.set_facecolor('#c6c8e4ff')
bottomfig.suptitle('Bottom')

top_axs = topfig.subplots(2, 4)
bottom_axs = bottomfig.subplots(3, 7)

plt.show()
